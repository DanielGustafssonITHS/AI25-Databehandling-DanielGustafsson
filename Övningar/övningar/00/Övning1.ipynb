# %% [markdown]
# ### Övning 1a,

# %%
import pandas as pd

data = {"Kommun": ["Malmö", "Sockholm", "Göteborg", "Uppsala"],
        "Population": [347949, 975551, 583056, 233839]}


df = pd.DataFrame(data)

df["Pop %"] = [3.4, 9.4, 5.6, 2.3]

print(df)
# Out:
#      Kommun  Population  Pop %
# 0     Malmö      347949    3.4
# 1  Sockholm      975551    9.4
# 2  Göteborg      583056    5.6
# 3   Uppsala      233839    2.3

# %% [markdown]
# ### 1b,

# %%
print(df.loc[2])
# Out:
# Kommun        Göteborg
# Population      583056
# Pop %              5.6
# Name: 2, dtype: object

# %% [markdown]
# ### 1c,

# %%
desc_order = df.sort_values("Population", ascending=False)

print(desc_order)
# Out:
#      Kommun  Population  Pop %
# 1  Sockholm      975551    9.4
# 2  Göteborg      583056    5.6
# 0     Malmö      347949    3.4
# 3   Uppsala      233839    2.3

# %% [markdown]
# ### 1d,

# %%
filtered_order = desc_order[desc_order["Population"] >= 250000]

print(filtered_order)
# Out:
#      Kommun  Population  Pop %
# 1  Sockholm      975551    9.4
# 2  Göteborg      583056    5.6
# 0     Malmö      347949    3.4

# %% [markdown]
# ### 1e,

# %%
print(desc_order)
# Out:
#      Kommun  Population  Pop %
# 1  Sockholm      975551    9.4
# 2  Göteborg      583056    5.6
# 0     Malmö      347949    3.4
# 3   Uppsala      233839    2.3
